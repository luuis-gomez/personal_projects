# %%
import pandas as pd
#We impor pandas

# %%
df = pd.read_csv(r'/content/diabetes.csv')
#Function to read data in .csv format

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
inputs = df.drop("Outcome",axis = 1) 
#Define input features

# %%
inputs
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y = df['Outcome']
#Defines pur expected answer

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs,y,random_state=42,test_size=.2)

# %%
#train_test_ funcition trains our data to get 
#input (our x value
#y is the expected answer 
#random_state ensures the ability to duplicate (chooses random same random data on an experiment in order to duplicate the same result)

# %%
X_train
#We see our data is missing 20 percent selected of the data and is randomize
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 60             2       84              0              0        0   0.0
# 618            9      112             82             24        0  28.2
# 346            1      139             46             19       83  28.7
# 294            0      161             50              0        0  21.9
# 231            6      134             80             37      370  46.2
# ..           ...      ...            ...            ...      ...   ...
# 71             5      139             64             35      140  28.6
# 106            1       96            122              0        0  22.4
# 270           10      101             86             37        0  45.6
# 435            0      141              0              0        0  42.4
# 102            0      125             96              0        0  22.5
#
#      DiabetesPedigreeFunction  Age
# 60                      0.304   21
# 618                     1.282   50
# ...

# %%
y_train
# Out:
# 60     0
# 618    1
# 346    0
# 294    0
# 231    1
#       ..
# 71     0
# 106    0
# 270    1
# 435    1
# 102    0
# Name: Outcome, Length: 614, dtype: int64

# %%
import tensorflow as tf

# %%
inputs = tf.keras.Input(shape=(8))
# redefined 'inputs' we use this function to initialize to reate an input layer
x = tf.keras.layers.Dense(1000,activation='relu')(inputs)
x = tf.keras.layers.Dense(1000,activation='relu')(x)
x = tf.keras.layers.Dense(1000,activation='relu')(inputs)
x = tf.keras.layers.Dense(1000,activation='relu')(inputs)
x = tf.keras.layers.Dense(1000,activation='relu')(inputs)

#we define x using a Dense Layer with 1000x1000 neurons
#Actvation as 'relu'
output = tf.keras.layers.Dense(1,activation='sigmoid')(x)
#define output with a layer in 'sigmoid' for binary prediction

# %%
model = tf.keras.Model(inputs,output)
#We define model as its input layer and output layer

# %%
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_12 (InputLayer)       [(None, 8)]               0
#
#  dense_31 (Dense)            (None, 1000)              9000
#
#  dense_32 (Dense)            (None, 1)                 1001
#
# ...
# Total params: 10,001
# Trainable params: 10,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=["accuracy",tf.keras.metrics.BinaryAccuracy()]
              )

# %%
attempt_1 = model.fit(
    X_train,y_train,
    epochs=10000,
    validation_data=(X_test,y_test),
    callbacks=[tf.keras.callbacks.EarlyStopping(patience=50)])
# Out:
# Epoch 1/10000
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3140 - accuracy: 0.8534 - binary_accuracy: 0.8534 - val_loss: 1.0908 - val_accuracy: 0.6753 - val_binary_accuracy: 0.6753
# Epoch 2/10000
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2766 - accuracy: 0.8811 - binary_accuracy: 0.8811 - val_loss: 1.0450 - val_accuracy: 0.6818 - val_binary_accuracy: 0.6818
# Epoch 3/10000
# 20/20 [==============================] - 0s 7ms/step - loss: 0.2851 - accuracy: 0.8681 - binary_accuracy: 0.8681 - val_loss: 1.0753 - val_accuracy: 0.6818 - val_binary_accuracy: 0.6818
# Epoch 4/10000
# 20/20 [==============================] - 0s 7ms/step - loss: 0.3649 - accuracy: 0.8469 - binary_accuracy: 0.8469 - val_loss: 1.2243 - val_accuracy: 0.6818 - val_binary_accuracy: 0.6818
# Epoch 5/10000
# ...
